# %%
from keras.preprocessing.image import ImageDataGenerator

path = "./Dataset/"
Imagesize = 128

train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory(path+'train',
                                                 target_size=(Imagesize, Imagesize),
                                                 batch_size=10,
                                                 color_mode='grayscale',
                                                 class_mode='categorical')

test_set = test_datagen.flow_from_directory(path+'test',
                                            target_size=(Imagesize , Imagesize),
                                            batch_size=10,
                                            color_mode='grayscale',
                                            class_mode='categorical')
# Out:
# Found 12845 images belonging to 27 classes.
# Found 4270 images belonging to 27 classes.

# %%
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense , Dropout

classifier = Sequential()

# First convolution layer and pooling
classifier.add(Convolution2D(32, (3, 3), input_shape=(Imagesize, Imagesize, 1), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))
# Second convolution layer and pooling
classifier.add(Convolution2D(32, (3, 3), activation='relu'))
# input_shape is going to be the pooled feature maps from the previous convolution layer
classifier.add(MaxPooling2D(pool_size=(2, 2)))
classifier.add(Convolution2D(16, (3, 3), activation='relu'))
# input_shape is going to be the pooled feature maps from the previous convolution layer
classifier.add(MaxPooling2D(pool_size=(2, 2)))
classifier.add(Convolution2D(16, (3, 3), activation='relu'))
# input_shape is going to be the pooled feature maps from the previous convolution layer
classifier.add(MaxPooling2D(pool_size=(2, 2)))

# Flattening the layers
classifier.add(Flatten())

# Adding a fully connected layer
classifier.add(Dense(units=128, activation='relu'))
classifier.add(Dropout(0.40))
classifier.add(Dense(units=96, activation='relu'))
classifier.add(Dropout(0.40))
classifier.add(Dense(units=64, activation='relu'))
classifier.add(Dense(units=27, activation='softmax')) # softmax for more than 2

# %%
classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) # categorical_crossentropy for more than 2
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      320
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 16)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 16)        2320
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 128)               73856
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 96)                12384
#
#  dropout_1 (Dropout)         (None, 96)                0
#
#  dense_2 (Dense)             (None, 64)                6208
#
#  dense_3 (Dense)             (None, 27)                1755
#
# =================================================================
# Total params: 110,715
# Trainable params: 110,715
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = classifier.fit_generator(
        generator = training_set,
        steps_per_epoch=training_set.n//training_set.batch_size,
        epochs=20,
        validation_data=test_set,
        validation_steps = test_set.n//test_set.batch_size,
        )# No of images in test set
# Out:
# Epoch 1/20
# C:\Users\Smit Pethani\AppData\Local\Temp\ipykernel_17240\2865783716.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = classifier.fit_generator(
# 1284/1284 [==============================] - 107s 82ms/step - loss: 1.7095 - accuracy: 0.4530 - val_loss: 0.2270 - val_accuracy: 0.9454
# Epoch 2/20
# 1284/1284 [==============================] - 107s 84ms/step - loss: 0.5500 - accuracy: 0.8119 - val_loss: 0.0558 - val_accuracy: 0.9834
# Epoch 3/20
# 1284/1284 [==============================] - 108s 84ms/step - loss: 0.3392 - accuracy: 0.8884 - val_loss: 0.0273 - val_accuracy: 0.9930
# Epoch 4/20
# 1284/1284 [==============================] - 112s 87ms/step - loss: 0.2532 - accuracy: 0.9162 - val_loss: 0.0116 - val_accuracy: 0.9963
# Epoch 5/20
# 1284/1284 [==============================] - 120s 93ms/step - loss: 0.1946 - accuracy: 0.9367 - val_loss: 0.0058 - val_accuracy: 0.9986
# Epoch 6/20
# 1284/1284 [==============================] - 115s 89ms/step - loss: 0.1711 - accuracy: 0.9454 - val_loss: 0.0046 - val_accuracy: 0.9988
# Epoch 7/20
# 1284/1284 [==============================] - 124s 96ms/step - loss: 0.1486 - accuracy: 0.9511 - val_loss: 0.0047 - val_accuracy: 0.9988
# Epoch 8/20
# 1284/1284 [==============================] - 120s 94ms/step - loss: 0.1402 - accuracy: 0.9554 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 9/20
# 1284/1284 [==============================] - 108s 84ms/step - loss: 0.1218 - accuracy: 0.9625 - val_loss: 0.0076 - val_accuracy: 0.9974
# Epoch 10/20
# 1284/1284 [==============================] - 110s 85ms/step - loss: 0.1086 - accuracy: 0.9655 - val_loss: 0.0062 - val_accuracy: 0.9972
# Epoch 11/20
# 1284/1284 [==============================] - 102s 79ms/step - loss: 0.0952 - accuracy: 0.9711 - val_loss: 0.0056 - val_accuracy: 0.9977
# Epoch 12/20
# 1284/1284 [==============================] - 105s 82ms/step - loss: 0.1054 - accuracy: 0.9701 - val_loss: 9.8784e-04 - val_accuracy: 0.9998
# Epoch 13/20
# 1284/1284 [==============================] - 111s 87ms/step - loss: 0.0890 - accuracy: 0.9735 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 14/20
# 1284/1284 [==============================] - 107s 83ms/step - loss: 0.0891 - accuracy: 0.9731 - val_loss: 0.0016 - val_accuracy: 0.9995
# Epoch 15/20
# 1284/1284 [==============================] - 109s 85ms/step - loss: 0.0835 - accuracy: 0.9753 - val_loss: 0.0030 - val_accuracy: 0.9988
# Epoch 16/20
# 1284/1284 [==============================] - 107s 83ms/step - loss: 0.0762 - accuracy: 0.9780 - val_loss: 0.0012 - val_accuracy: 0.9998
# Epoch 17/20
# 1284/1284 [==============================] - 111s 86ms/step - loss: 0.0752 - accuracy: 0.9776 - val_loss: 3.2317e-04 - val_accuracy: 1.0000
# Epoch 18/20
# 1284/1284 [==============================] - 108s 84ms/step - loss: 0.0695 - accuracy: 0.9811 - val_loss: 6.8568e-04 - val_accuracy: 1.0000
# Epoch 19/20
# 1284/1284 [==============================] - 107s 83ms/step - loss: 0.0642 - accuracy: 0.9815 - val_loss: 0.0047 - val_accuracy: 0.9988
# Epoch 20/20
# 1284/1284 [==============================] - 108s 84ms/step - loss: 0.0633 - accuracy: 0.9805 - val_loss: 2.7374e-04 - val_accuracy: 1.0000

# %%
import matplotlib.pyplot as plt

plt.style.use('dark_background')

plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
model_json = classifier.to_json()
with open("Models/model-manish.json", "w") as json_file:
    json_file.write(model_json)
print('Model Saved')
classifier.save_weights('Models/model-manish.h5')
print('Weights saved')
# Out:
# Model Saved
# Weights saved
